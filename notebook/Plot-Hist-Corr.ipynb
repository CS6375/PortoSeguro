# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns

# %%
train = pd.read_csv("../data/train.csv", na_values=['-1'])

# %%
train.describe()
# Out:
#                  id         target      ps_ind_01  ps_ind_02_cat  \
# count  5.952120e+05  595212.000000  595212.000000  594996.000000
# mean   7.438036e+05       0.036448       1.900378       1.359799
# std    4.293678e+05       0.187401       1.983789       0.663193
# min    7.000000e+00       0.000000       0.000000       1.000000
# 25%    3.719915e+05       0.000000       0.000000       1.000000
# 50%    7.435475e+05       0.000000       1.000000       1.000000
# 75%    1.115549e+06       0.000000       3.000000       2.000000
# max    1.488027e+06       1.000000       7.000000       4.000000
#
#            ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  ps_ind_06_bin  \
# count  595212.000000  595129.000000  589403.000000  595212.000000
# mean        4.423318       0.416992       0.419038       0.393742
# std         2.699902       0.493062       1.350023       0.488579
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
no_id_train = train.drop(['id'], axis=1)

# %%
cat_col = list(filter(lambda x : 'cat' in x, [x for x in train.columns]))
bin_col = list(filter(lambda x : 'bin' in x, [x for x in train.columns]))
num_col = list(filter(lambda x : not ('id' in x or 'bin' in x or 'cat' in x), [x for x in train.columns]))

ind_col = list(filter(lambda x : 'ind' in x, [x for x in train.columns]))
reg_col = list(filter(lambda x : 'reg' in x, [x for x in train.columns]))
car_col = list(filter(lambda x : 'car' in x, [x for x in train.columns]))
calc_col = list(filter(lambda x : 'calc' in x, [x for x in train.columns]))

# %%
plt.figure()
no_id_train[ind_col].hist(histtype='bar', 
                          normed=True, 
                          color='k', 
                          alpha=0.6, 
                          bins=50, 
                          layout=(3, 6), 
                          figsize = (24, 7.5))
plt.savefig('ind_col.pdf', bbox_inches='tight')
plt.close()

# %%
plt.figure()
no_id_train[reg_col].hist(histtype='bar', 
                          normed=True, 
                          color='k', 
                          alpha=0.6, 
                          bins=50, 
                          layout=(1, 3), 
                          figsize = (12, 2.5))
plt.savefig('reg_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
plt.figure()
no_id_train[car_col].hist(histtype='bar', 
                          normed=True, 
                          color='k', 
                          alpha=0.6, 
                          bins=50, 
                          layout=(3, 6), 
                          figsize = (24, 7.5))
plt.savefig('car_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
plt.figure()
no_id_train[calc_col].hist(histtype='bar', 
                          normed=True, 
                          color='k', 
                          alpha=0.6, 
                          bins=50, 
                          layout=(4, 6), 
                          figsize = (24, 10))
plt.savefig('calc_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
sns.set(style="white")

plt.figure()

# Compute the correlation matrix
corr = train[ind_col].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=False, linewidths=.5, cbar_kws={"shrink": .5})

plt.savefig('corr_ind_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
sns.set(style="white")

plt.figure()

# Compute the correlation matrix
corr = train[reg_col].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(2, 1.8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=False, linewidths=.5, cbar_kws={"shrink": .5})

plt.savefig('corr_reg_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
sns.set(style="white")

plt.figure()

# Compute the correlation matrix
corr = train[car_col].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(8, 7))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=False, linewidths=.5, cbar_kws={"shrink": .5})

plt.savefig('corr_car_col.pdf', bbox_inches='tight')
plt.close('all')

# %%
sns.set(style="white")

plt.figure()

# Compute the correlation matrix
corr = train[calc_col].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(7, 6))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=False, linewidths=.5, cbar_kws={"shrink": .5})

plt.savefig('corr_calc_col.pdf', bbox_inches='tight')
plt.close('all')
